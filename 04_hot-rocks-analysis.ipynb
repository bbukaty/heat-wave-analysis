# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file into a DataFrame
file_path = 'external/hot-rocks/supplementary_fort_ross_temps.csv'
data = pd.read_csv(file_path)
data.head()
# Out:
#              dt unit  temp rock  elev
# 0  6/19/15 0:14    C  11.0  R03  high
# 1  6/19/15 0:29    C  11.0  R03  high
# 2  6/19/15 0:44    C  11.0  R03  high
# 3  6/19/15 0:59    C  11.0  R03  high
# 4  6/19/15 1:14    C  11.0  R03  high

# %%
# Get the data back in chronological order and set timestamps as index
data['dt'] = pd.to_datetime(data['dt'], format='%m/%d/%y %H:%M')
data = data.sort_values(by='dt')
data.set_index('dt', inplace=True)
data.head()
# Out:
#                     unit  temp rock  elev
# dt
# 2015-06-19 00:00:00    C  11.0  R05   low
# 2015-06-19 00:01:00    C  10.5  R07   low
# 2015-06-19 00:02:00    C  10.5  R15   low
# 2015-06-19 00:02:00    C  11.0  R33  high
# 2015-06-19 00:03:00    C  11.0  R06   low

# %%
data_high = data[data['elev'] == 'high']
data_low = data[data['elev'] == 'low']

# Plotting the temperatures over time for both high and low elevations
plt.figure(figsize=(40, 8))
plt.plot(data_high.index, data_high['temp'], label='High Elevation Temperature', color='blue')
plt.plot(data_low.index, data_low['temp'], label='Low Elevation Temperature', color='red')
plt.title('Temperature Over Time at Fort Ross')
plt.xlabel('Date and Time')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
